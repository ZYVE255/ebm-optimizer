# %% [markdown]
# <h1><center>Using Zach_OPTIMIZER to Check Temporal Resolution</center></h1>

# %%
#==========Imports==========
import numpy as np
import matplotlib.pyplot as plt
import astropy.constants as const
import time
from scipy import interpolate
import Zach_OPTIMIZER.EBMFunctions as opt

import Bell_EBM as ebm

# %%
#==========Set Up System==========
planet = ebm.Planet(rad=1.900*const.R_jup.value, mass=1.470*const.M_jup.value,
                    Porb=1.09142030, a=0.02340*const.au.value, inc=83.37, vWind=5e3, nlat = 16)
star = ebm.Star(teff=6300., rad=1.59, mass=1.20)
system = ebm.System(star, planet)

# %% [markdown]
# ### Use CreateBaseline function to create a high temporal resolution baseline
# ##### We feed the star and planet into the function and also a fixed spacial resolution of 16, the function then returns us the times, maps, and lightcurve or the baseline

# %%
blt, blm, blc = opt.CreateBaseline(star,planet,spacial=16, orbit=1, temporal=10000)

# %% [markdown]
# ### Create a test array of 10 points
# ##### We keep a fixed spacial resolution of 16 to match the baseline, we test temporal resolution from 100 to 1000

# %%
p = np.zeros(shape=((15),2))
p[:,1]=16
for i in range(0,15):
    p[i,0] = (i*100)+100
p
# Out:
# array([[ 100.,   16.],
#        [ 200.,   16.],
#        [ 300.,   16.],
#        [ 400.,   16.],
#        [ 500.,   16.],
#        [ 600.,   16.],
#        [ 700.,   16.],
#        [ 800.,   16.],
#        [ 900.,   16.],
#        [1000.,   16.],
#        [1100.,   16.],
#        [1200.,   16.],
#        [1300.,   16.],
#        [1400.,   16.],
#        [1500.,   16.]])

# %% [markdown]
# ### Run tests on the data points we created
# ##### We pass in the planet, the star, the points we created, the baseline lightcurve, and the baseline times. We also set loops to 10 to make sure we get a nice average for the time to run. The function returns to us array of the tested point's lightcurve and the data set associated with the test

# %%
lc, data = opt.RunTests(star,planet,p,blc,blt,loops=10)

# %%
data
# Out:
# array([[1.00000000e+02, 1.60000000e+01, 8.67058992e+01, 2.27413256e+00],
#        [2.00000000e+02, 1.60000000e+01, 1.05462742e+02, 1.12376404e+00],
#        [3.00000000e+02, 1.60000000e+01, 1.27828121e+02, 7.41018067e-01],
#        [4.00000000e+02, 1.60000000e+01, 1.51854610e+02, 5.49831432e-01],
#        [5.00000000e+02, 1.60000000e+01, 1.72617626e+02, 4.35183438e-01],
#        [6.00000000e+02, 1.60000000e+01, 2.00681472e+02, 3.58779153e-01],
#        [7.00000000e+02, 1.60000000e+01, 2.18472004e+02, 3.04218737e-01],
#        [8.00000000e+02, 1.60000000e+01, 2.40724874e+02, 2.63306308e-01],
#        [9.00000000e+02, 1.60000000e+01, 2.62854266e+02, 2.31490283e-01],
#        [1.00000000e+03, 1.60000000e+01, 2.82221079e+02, 2.06040497e-01],
#        [1.10000000e+03, 1.60000000e+01, 3.02600217e+02, 1.85219971e-01],
#        [1.20000000e+03, 1.60000000e+01, 3.23868752e+02, 1.67870937e-01],
#        [1.30000000e+03, 1.60000000e+01, 3.45509553e+02, 1.53191989e-01],
#        [1.40000000e+03, 1.60000000e+01, 3.70639205e+02, 1.40610825e-01],
#        [1.50000000e+03, 1.60000000e+01, 3.87044692e+02, 1.29707748e-01]])

# %% [markdown]
# ### Lets check out some graphs!

# %%
y = data[:,2]
x = data[:,0]
plt.scatter(x, y)
plt.xlabel("Temporal Resolution")
plt.ylabel("Time to Compute (ms)")
plt.title('Time to Compute Compared to Temporal Resolution')
plt.grid(True, linestyle='-.')
plt.show()

y = data[:,3]
x = data[:,0]
plt.scatter(x, y)
plt.xlabel("Temporal Resolution")
plt.ylabel("Largest Error (ppm)")
plt.title('Largest Error Compared to Temporal Resolution')
plt.grid(True, linestyle='-.')
plt.show()

# %% [markdown]
# <h1><center>Testing Lightcurves at Low Temporal Resolution</center></h1>

# %% [markdown]
# ### Re-build the baseline, not necessary, but just incase the above one wasn't done

# %%
blt, blm, blc = opt.CreateBaseline(star,planet,spacial=16, orbit=1, temporal=10000)

# %% [markdown]
# ### Lets define some points where we want to test the function

# %%
d = np.zeros(shape=((5),2))
d[:,1]=16
for i in range(0,5):
    d[i,0] = (i*20)+60
d
# Out:
# array([[ 60.,  16.],
#        [ 80.,  16.],
#        [100.,  16.],
#        [120.,  16.],
#        [140.,  16.]])

# %% [markdown]
# ### Run the test function on the points

# %%
lcs, data = opt.RunTests(star, planet, d, blc, blt)

# %%
data
# Out:
# array([[ 60.        ,  16.        ,  82.33499527,   3.80878389],
#        [ 80.        ,  16.        ,  78.29141617,   2.84988269],
#        [100.        ,  16.        ,  82.84187317,   2.27413256],
#        [120.        ,  16.        ,  87.32175827,   1.89042231],
#        [140.        ,  16.        ,  91.26710892,   1.61647033]])

# %% [markdown]
# ### Lets check the graphs!
# ##### By looking at the differences between the baseline and the test runs we can see where the model is having difficulties

# %%
plt.title("Error with Different Temporal Resolutions")
plt.ylabel("Error (ppm)")
plt.plot((blc-blc)*1e6, 'k', linestyle = "--", lw=0.75)
for i in range (1,lcs.shape[0]):
    plt.plot((blc-lcs[i])*1e6, label=str(data[i,0])+" Time Steps")
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
